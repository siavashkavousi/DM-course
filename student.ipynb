# %%
import warnings
warnings.filterwarnings('ignore')

% matplotlib inline

import numpy as np
import pandas as pd

pd.options.display.max_columns = 100
import matplotlib.pyplot as plt
import matplotlib

matplotlib.style.use('ggplot')

pd.options.display.max_rows = 100

import seaborn as sns

sns.set(color_codes=True)

# %%
train_df = pd.read_csv('datasets/students_grades/train.csv', header=None,
                       names=['g0', 'g1', 'g2', 'g3', 'g4', 'g5', 'g6'])
train_df.head()
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>g0</th>
#       <th>g1</th>
#       <th>g2</th>
#       <th>g3</th>
#       <th>g4</th>
#       <th>g5</th>
#       <th>g6</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>9.00</td>
#       <td>10.00</td>
#       <td>0.0</td>
#       <td>9.00</td>
#       <td>17.5</td>
#       <td>8.50</td>
#       <td>11.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>11.50</td>
#       <td>0.00</td>
#       <td>0.0</td>
#       <td>12.75</td>
#       <td>0.0</td>
#       <td>12.97</td>
#       <td>13.3</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>15.75</td>
#       <td>0.00</td>
#       <td>0.0</td>
#       <td>12.50</td>
#       <td>0.0</td>
#       <td>10.72</td>
#       <td>13.7</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>16.00</td>
#       <td>13.00</td>
#       <td>0.0</td>
#       <td>10.00</td>
#       <td>20.0</td>
#       <td>14.75</td>
#       <td>13.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>9.25</td>
#       <td>12.25</td>
#       <td>0.0</td>
#       <td>9.00</td>
#       <td>9.0</td>
#       <td>12.50</td>
#       <td>13.6</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
train_df.describe()
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>g0</th>
#       <th>g1</th>
#       <th>g2</th>
#       <th>g3</th>
#       <th>g4</th>
#       <th>g5</th>
#       <th>g6</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>240.000000</td>
#       <td>240.000000</td>
#       <td>240.000000</td>
#       <td>240.000000</td>
#       <td>240.000000</td>
#       <td>240.000000</td>
#       <td>240.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>13.224458</td>
#       <td>10.447000</td>
#       <td>4.667292</td>
#       <td>12.344167</td>
#       <td>10.470917</td>
#       <td>12.938083</td>
#       <td>13.730208</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>3.839535</td>
#       <td>5.970009</td>
#       <td>6.404387</td>
#       <td>4.330254</td>
#       <td>7.391725</td>
#       <td>4.617273</td>
#       <td>3.349091</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>5.000000</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>10.000000</td>
#       <td>9.000000</td>
#       <td>0.000000</td>
#       <td>10.000000</td>
#       <td>0.000000</td>
#       <td>10.500000</td>
#       <td>11.000000</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>13.000000</td>
#       <td>11.335000</td>
#       <td>0.000000</td>
#       <td>12.125000</td>
#       <td>12.000000</td>
#       <td>13.250000</td>
#       <td>13.650000</td>
#     </tr>
#     <tr>
#       <th>75%</th>
#       <td>16.500000</td>
#       <td>14.812500</td>
#       <td>9.900000</td>
#       <td>15.500000</td>
#       <td>17.000000</td>
#       <td>16.137500</td>
#       <td>16.225000</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>20.000000</td>
#       <td>20.000000</td>
#       <td>20.000000</td>
#       <td>20.000000</td>
#       <td>20.000000</td>
#       <td>20.000000</td>
#       <td>20.000000</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
sns.regplot(x="g0", y="g6", data=train_df)

# %%
sns.regplot(x='g1', y='g6', data=train_df)

# %%
sns.regplot(x='g2', y='g6', data=train_df)

# %%
sns.regplot(x='g3', y='g6', data=train_df)

# %%
sns.regplot(x='g4', y='g6', data=train_df)

# %%
sns.regplot(x='g5', y='g6', data=train_df)

# %% [markdown]
# Removing zeros for better visualization

# %%
sns.regplot(x='g0', y='g6', data=train_df[train_df['g0'] != 0])

# %%
sns.regplot(x='g1', y='g6', data=train_df[train_df['g1'] != 0])

# %%
sns.regplot(x='g2', y='g6', data=train_df[train_df['g2'] != 0])

# %%
sns.regplot(x='g3', y='g6', data=train_df[train_df['g3'] != 0])

# %%
sns.regplot(x='g4', y='g6', data=train_df[train_df['g4'] != 0])

# %%
sns.regplot(x='g5', y='g6', data=train_df[train_df['g5'] != 0])

# %%
sns.jointplot(x="g0", y="g6", data=train_df[train_df['g0'] != 0],
              kind="kde", space=0, color="g")

# %%
sns.jointplot(x="g1", y="g6", data=train_df[train_df['g1'] != 0],
              kind="kde", space=0, color="g")

# %%
sns.jointplot(x="g2", y="g6", data=train_df[train_df['g2'] != 0],
              kind="kde", space=0, color="g")

# %%
sns.jointplot(x="g3", y="g6", data=train_df[train_df['g3'] != 0],
              kind="kde", space=0, color="g")

# %%
sns.jointplot(x="g4", y="g6", data=train_df[train_df['g4'] != 0],
              kind="kde", space=0, color="g")

# %%
sns.jointplot(x="g5", y="g6", data=train_df[train_df['g5'] != 0],
              kind="kde", space=0, color="g")

# %% [markdown]
# checking missing values

# %%
g0_count = train_df.loc[train_df['g0'] == 0, 'g0'].count()
g1_count = train_df.loc[train_df['g1'] == 0, 'g1'].count()
g2_count = train_df.loc[train_df['g2'] == 0, 'g2'].count()
g3_count = train_df.loc[train_df['g3'] == 0, 'g3'].count()
g4_count = train_df.loc[train_df['g4'] == 0, 'g4'].count()
g5_count = train_df.loc[train_df['g5'] == 0, 'g5'].count()
g6_count = train_df.loc[train_df['g6'] == 0, 'g6'].count()

g0_count, g1_count, g2_count, g3_count, g4_count, g5_count, g6_count
# Out:
# (2, 47, 151, 12, 69, 15, 0)

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/siavash/anaconda3/envs/ml/lib/python3.6/site-packages/pandas/core/ops.py in na_op(x, y)
#     876         try:
# --> 877             result = op(x, y)
#     878         except TypeError:
#
# /home/siavash/anaconda3/envs/ml/lib/python3.6/site-packages/pandas/core/ops.py in <lambda>(x, y)
#     124                  xor=bool_method(operator.xor, names('xor'), op('^')),
# --> 125                  rand_=bool_method(lambda x, y: operator.and_(y, x),
#     126                                    names('rand_'), op('&')),
#
# TypeError: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /home/siavash/anaconda3/envs/ml/lib/python3.6/site-packages/pandas/core/ops.py in na_op(x, y)
#     894                         y = bool(y)
# --> 895                     result = lib.scalar_binop(x, y, op)
#     896                 except:
#
# pandas/lib.pyx in pandas.lib.scalar_binop (pandas/lib.c:16177)()
#
# ValueError: Buffer dtype mismatch, expected 'Python object' but got 'double'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-a737c652c06c> in <module>()
# ----> 1 g0_count = train_df[train_df['g0'] == 0 & train_df['g1']].count()
#
# /home/siavash/anaconda3/envs/ml/lib/python3.6/site-packages/pandas/core/ops.py in wrapper(self, other)
#     927                       is_integer_dtype(np.asarray(other)) else fill_bool)
#     928             return filler(self._constructor(
# --> 929                 na_op(self.values, other),
#     930                 index=self.index)).__finalize__(self)
#     931
#
# /home/siavash/anaconda3/envs/ml/lib/python3.6/site-packages/pandas/core/ops.py in na_op(x, y)
#     897                     raise TypeError("cannot compare a dtyped [{0}] array with "
#     898                                     "a scalar of type [{1}]".format(
# --> 899                                         x.dtype, type(y).__name__))
#     900
#     901         return result
#
# TypeError: cannot compare a dtyped [float64] array with a scalar of type [bool]
